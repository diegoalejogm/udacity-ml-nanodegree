# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.224731
# Minibatch accuracy: 12.5%
# Validation accuracy: 14.0%
# Minibatch loss at step 50: 1.790658
# Minibatch accuracy: 25.0%
# Validation accuracy: 35.9%
# Minibatch loss at step 100: 1.220836
# Minibatch accuracy: 68.8%
# Validation accuracy: 64.5%
# Minibatch loss at step 150: 0.365391
# Minibatch accuracy: 87.5%
# Validation accuracy: 72.0%
# Minibatch loss at step 200: 0.823868
# Minibatch accuracy: 81.2%
# Validation accuracy: 76.1%
# Minibatch loss at step 250: 1.230470
# Minibatch accuracy: 68.8%
# Validation accuracy: 76.5%
# Minibatch loss at step 300: 0.391951
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.9%
# Minibatch loss at step 350: 0.418690
# Minibatch accuracy: 93.8%
# Validation accuracy: 73.7%
# Minibatch loss at step 400: 0.273128
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.8%
# Minibatch loss at step 450: 0.986355
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.4%
# Minibatch loss at step 500: 0.566493
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.3%
# Minibatch loss at step 550: 0.825007
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.2%
# Minibatch loss at step 600: 0.283964
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.2%
# Minibatch loss at step 650: 0.976160
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.8%
# Minibatch loss at step 700: 0.985628
# Minibatch accuracy: 62.5%
# Validation accuracy: 81.5%
# Minibatch loss at step 750: 0.100825
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 800: 0.735856
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.3%
# Minibatch loss at step 850: 0.882104
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.3%
# Minibatch loss at step 900: 0.753842
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.4%
# Minibatch loss at step 950: 0.525879
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.6%
# Minibatch loss at step 1000: 0.423751
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.8%
# Test accuracy: 89.0%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
    
  # Convolutions
  def conv2d(x, W, b, strides=1):
    conv = tf.nn.conv2d(x, W, [1, strides, strides, 1], padding='SAME')        
    conv = tf.nn.bias_add(conv,b)
    return tf.nn.relu(conv)

  # Pooling
  def maxpool2d(x, k=2, s=2):
    return tf.nn.max_pool(x, ksize=[1,k,k,1], strides=[1,s,s,1], padding='SAME')

  # Model: Deep neural network .
  def model(data):  
    hidden = maxpool2d(conv2d(data, layer1_weights, layer1_biases))
    hidden = maxpool2d(conv2d(hidden, layer2_weights, layer2_biases))
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.424291
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.5%
# Minibatch loss at step 50: 1.372590
# Minibatch accuracy: 50.0%
# Validation accuracy: 54.6%
# Minibatch loss at step 100: 0.751465
# Minibatch accuracy: 56.2%
# Validation accuracy: 63.8%
# Minibatch loss at step 150: 0.403392
# Minibatch accuracy: 81.2%
# Validation accuracy: 74.4%
# Minibatch loss at step 200: 1.063100
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.3%
# Minibatch loss at step 250: 1.255385
# Minibatch accuracy: 62.5%
# Validation accuracy: 75.5%
# Minibatch loss at step 300: 0.470863
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.6%
# Minibatch loss at step 350: 0.533374
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.9%
# Minibatch loss at step 400: 0.291683
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.0%
# Minibatch loss at step 450: 0.904692
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.0%
# Minibatch loss at step 500: 0.525851
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.9%
# Minibatch loss at step 550: 0.674521
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.3%
# Minibatch loss at step 600: 0.318543
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.8%
# Minibatch loss at step 650: 0.736255
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.5%
# Minibatch loss at step 700: 1.019669
# Minibatch accuracy: 62.5%
# Validation accuracy: 83.5%
# Minibatch loss at step 750: 0.033086
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.8%
# Minibatch loss at step 800: 0.558442
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.6%
# Minibatch loss at step 850: 0.814663
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.0%
# Minibatch loss at step 900: 0.624695
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.2%
# Minibatch loss at step 950: 0.564940
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.1%
# Minibatch loss at step 1000: 0.418842
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.8%
# Test accuracy: 90.5%

# %% [markdown]
# Test accuracy is higher than the previous network which doesn't use pooling. So it's possitive effects can be observed. This basic deep neural network behaves well enough for the amount of iterations provided.

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %% [markdown]
# First of all I will implement a variation of LeNet5 architecture, mixed with the previous neural network. It will use two convolutions, two maxpoolings, and a fully connected network with 1 hidden layer.
#
# The second implementation will be a variation of the one just mentioned, adding regularization of type L2, dropouts and exponential decays.
#
# The idea is to compare the performance of convolutional networks including the previously taught techniques.
#
# ### Case A

# %%
graph = tf.Graph()
train_size = train_labels.shape[0]
patch_size = 5
depth = 16
num_hidden = 64

with graph.as_default():
    SEED=27
    # Input data.
    tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)

    def weight(patch_size, channels, depth):
        return tf.Variable(tf.truncated_normal([patch_size, patch_size, channels, depth], stddev=0.1))
  
    def conv2d(x, W, b, strides=1):
        conv = tf.nn.conv2d(x,W,[1,strides,strides,1], padding='VALID')
        conv = tf.nn.bias_add(conv,b)
        return tf.nn.relu(conv)

    def maxpool2d(x, s=2, k=2):
        return tf.nn.max_pool(x, ksize=[1,k,k,1], strides=[1,s,s,1], padding='VALID')
    
    # Variables
    layer1_weights = weight(patch_size, num_channels, depth)
    layer1_biases = tf.Variable(tf.zeros([depth]))
    layer2_weights = weight(patch_size, depth, depth)
    layer2_biases = tf.Variable(tf.zeros([depth]))
    size3 = ((image_size - patch_size + 1) // 2 - patch_size + 1) // 2
    layer3_weights = tf.Variable(tf.truncated_normal(
        [size3*size3*depth, num_hidden], stddev=0.1))
    layer3_biases = tf.Variable(tf.zeros([num_hidden]))
    layer4_weights = tf.Variable(tf.truncated_normal(
        [num_hidden,num_labels], stddev=0.1))
    layer4_biases = tf.Variable(tf.zeros([num_labels]))

    def main(dataset, train=False):
        # CONV 1: 28x28 --> 24x24
        conv = conv2d(dataset, layer1_weights, layer1_biases)
        # POOL 1: 24x24 --> 12x12
        pool = maxpool2d(conv)
        # CONV 2: 12x12 --> 7x7
        conv = conv2d(pool, layer2_weights, layer2_biases)
        # POOL 2: 7x7 --> 4x4
        pool = maxpool2d(conv)

        pool_shape = pool.get_shape().as_list()
        print(pool_shape)
        reshape = tf.reshape( pool,
            [pool_shape[0], pool_shape[1] * pool_shape[2] * pool_shape[3]])

        hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        return tf.matmul(hidden, layer4_weights) + layer4_biases

    logits = main(tf_train_dataset, train=True)
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))

    batch = tf.Variable(0)
    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(0.046).minimize(loss)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))
# Out:
# [16, 4, 4, 16]

# %%
# Training the network 

num_steps = 20001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 2.321826
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.1%
# Minibatch loss at step 50: 1.893064
# Minibatch accuracy: 37.5%
# Validation accuracy: 44.1%
# Minibatch loss at step 100: 1.152998
# Minibatch accuracy: 56.2%
# Validation accuracy: 60.2%
# Minibatch loss at step 150: 0.778394
# Minibatch accuracy: 81.2%
# Validation accuracy: 73.1%
# Minibatch loss at step 200: 1.015805
# Minibatch accuracy: 81.2%
# Validation accuracy: 74.8%
# Minibatch loss at step 250: 1.028913
# Minibatch accuracy: 68.8%
# Validation accuracy: 74.3%
# Minibatch loss at step 300: 0.474368
# Minibatch accuracy: 87.5%
# Validation accuracy: 79.6%
# Minibatch loss at step 350: 0.567590
# Minibatch accuracy: 87.5%
# Validation accuracy: 77.0%
# Minibatch loss at step 400: 0.171573
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.0%
# Minibatch loss at step 450: 1.191593
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.0%
# Minibatch loss at step 500: 0.688555
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.9%
# Minibatch loss at step 550: 0.922756
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.4%
# Minibatch loss at step 600: 0.382563
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.6%
# Minibatch loss at step 650: 0.925600
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.9%
# Minibatch loss at step 700: 0.863066
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.0%
# Minibatch loss at step 750: 0.035566
# Minibatch accuracy: 100.0%
# Validation accuracy: 82.1%
# Minibatch loss at step 800: 0.573500
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.3%
# Minibatch loss at step 850: 0.592756
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.4%
# Minibatch loss at step 900: 0.852267
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.8%
# Minibatch loss at step 950: 0.444898
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.0%
# Minibatch loss at step 1000: 0.520385
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.3%
# Minibatch loss at step 1050: 0.733432
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.2%
# Minibatch loss at step 1100: 0.680186
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.9%
# Minibatch loss at step 1150: 0.499452
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.6%
# Minibatch loss at step 1200: 0.789702
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.2%
# Minibatch loss at step 1250: 0.723662
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.1%
# Minibatch loss at step 1300: 0.464923
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.1%
# Minibatch loss at step 1350: 0.694999
# Minibatch accuracy: 68.8%
# Validation accuracy: 83.8%
# Minibatch loss at step 1400: 0.248670
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.2%
# Minibatch loss at step 1450: 0.148851
# Minibatch accuracy: 100.0%
# Validation accuracy: 84.7%
# Minibatch loss at step 1500: 0.637146
# Minibatch accuracy: 75.0%
# Validation accuracy: 83
f_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
    tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
    tf_valid_dataset = tf.constant(valid_dataset)
    tf_test_dataset = tf.constant(test_dataset)

    def weight(patch_size, channels, depth):
        return tf.Variable(tf.truncated_normal([patch_size, patch_size, channels, depth], stddev=0.1))
  
    def conv2d(x, W, b, strides=1):
        conv = tf.nn.conv2d(x,W,[1,strides,strides,1], padding='VALID')
        conv = tf.nn.bias_add(conv,b)
        return tf.nn.relu(conv)

    def maxpool2d(x, s=2, k=2):
        return tf.nn.max_pool(x, ksize=[1,k,k,1], strides=[1,s,s,1], padding='VALID')
    
    # Variables
    layer1_weights = weight(patch_size, num_channels, depth)
    layer1_biases = tf.Variable(tf.zeros([depth]))
    layer2_weights = weight(patch_size, depth, depth)
    layer2_biases = tf.Variable(tf.zeros([depth]))
    size3 = ((image_size - patch_size + 1) // 2 - patch_size + 1) // 2
    layer3_weights = tf.Variable(tf.truncated_normal(
        [size3*size3*depth, num_hidden], stddev=0.1))
    layer3_biases = tf.Variable(tf.zeros([num_hidden]))
    layer4_weights = tf.Variable(tf.truncated_normal(
        [num_hidden,num_labels], stddev=0.1))
    layer4_biases = tf.Variable(tf.zeros([num_labels]))

    def main(dataset, train=False):
        # CONV 1: 28x28 --> 24x24
        conv = conv2d(dataset, layer1_weights, layer1_biases)
        # POOL 1: 24x24 --> 12x12
        pool = maxpool2d(conv)
        # CONV 2: 12x12 --> 7x7
        conv = conv2d(pool, layer2_weights, layer2_biases)
        # POOL 2: 7x7 --> 4x4
        pool = maxpool2d(conv)

        pool_shape = pool.get_shape().as_list()
        print(pool_shape)
        reshape = tf.reshape( pool,
            [pool_shape[0], pool_shape[1] * pool_shape[2] * pool_shape[3]])

        hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
        
        # DROPOUTS
        if train:
            hidden = tf.nn.dropout(hidden, 0.5, seed=SEED)
        return tf.matmul(hidden, layer4_weights) + layer4_biases

    logits = main(tf_train_dataset, train=True)
    loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))

    # REGULARIZATION
    regularizers = (tf.nn.l2_loss(layer3_weights) + tf.nn.l2_loss(layer3_biases) +  
                    tf.nn.l2_loss(layer4_weights) + tf.nn.l2_loss(layer4_biases))
    loss += regularizers*5e-4

    # LEARNING RATE (EXP. DECAY)
    batch = tf.Variable(0)
    # Decay once per epoch, using an exponential schedule starting at 0.01.
    learning_rate = tf.train.exponential_decay(
        0.01,                # Base learning rate.
        batch * batch_size,  # Current index into the dataset.
        train_size,          # Decay step.
        0.95,                # Decay rate.
        staircase=True)
    
    # Optimizer.
    optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss, global_step=batch)

    # Predictions for the training, validation, and test data.
    train_prediction = tf.nn.softmax(logits)
    valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
    test_prediction = tf.nn.softmax(model(tf_test_dataset))
# Out:
# [16, 4, 4, 16]

# %%
num_steps = 20001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 2.379495
# Minibatch accuracy: 6.2%
# Validation accuracy: 12.9%
# Minibatch loss at step 50: 2.317511
# Minibatch accuracy: 6.2%
# Validation accuracy: 28.8%
# Minibatch loss at step 100: 2.320956
# Minibatch accuracy: 12.5%
# Validation accuracy: 31.5%
# Minibatch loss at step 150: 2.175359
# Minibatch accuracy: 37.5%
# Validation accuracy: 38.6%
# Minibatch loss at step 200: 1.977639
# Minibatch accuracy: 37.5%
# Validation accuracy: 43.6%
# Minibatch loss at step 250: 2.000486
# Minibatch accuracy: 43.8%
# Validation accuracy: 48.5%
# Minibatch loss at step 300: 1.422756
# Minibatch accuracy: 56.2%
# Validation accuracy: 60.1%
# Minibatch loss at step 350: 1.528840
# Minibatch accuracy: 43.8%
# Validation accuracy: 61.1%
# Minibatch loss at step 400: 1.156412
# Minibatch accuracy: 68.8%
# Validation accuracy: 66.1%
# Minibatch loss at step 450: 1.404627
# Minibatch accuracy: 62.5%
# Validation accuracy: 68.3%
# Minibatch loss at step 500: 2.093176
# Minibatch accuracy: 43.8%
# Validation accuracy: 71.5%
# Minibatch loss at step 550: 1.426305
# Minibatch accuracy: 56.2%
# Validation accuracy: 72.3%
# Minibatch loss at step 600: 0.599124
# Minibatch accuracy: 87.5%
# Validation accuracy: 71.5%
# Minibatch loss at step 650: 1.342199
# Minibatch accuracy: 68.8%
# Validation accuracy: 74.7%
# Minibatch loss at step 700: 1.358643
# Minibatch accuracy: 56.2%
# Validation accuracy: 74.6%
# Minibatch loss at step 750: 0.649621
# Minibatch accuracy: 81.2%
# Validation accuracy: 75.6%
# Minibatch loss at step 800: 0.845106
# Minibatch accuracy: 75.0%
# Validation accuracy: 75.7%
# Minibatch loss at step 850: 1.510862
# Minibatch accuracy: 62.5%
# Validation accuracy: 75.3%
# Minibatch loss at step 900: 1.395343
# Minibatch accuracy: 75.0%
# Validation accuracy: 75.8%
# Minibatch loss at step 950: 1.083521
# Minibatch accuracy: 62.5%
# Validation accuracy: 77.6%
# Minibatch loss at step 1000: 0.881894
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.1%
# Minibatch loss at step 1050: 1.340307
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.2%
# Minibatch loss at step 1100: 0.973057
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.2%
# Minibatch loss at step 1150: 1.042337
# Minibatch accuracy: 68.8%
# Validation accuracy: 78.1%
# Minibatch loss at step 1200: 1.342576
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.2%
# Minibatch loss at step 1250: 0.966177
# Minibatch accuracy: 81.2%
# Validation accuracy: 78.5%
# Minibatch loss at step 1300: 0.483257
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.8%
# Minibatch loss at step 1350: 1.107811
# Minibatch accuracy: 62.5%
# Validation accuracy: 78.3%
# Minibatch loss at step 1400: 1.018998
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.9%
# Minibatch loss at step 1450: 0.779550
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.5%
# Minibatch loss at step 1500: 1.506416
# Minibatch accuracy: 68.8%
# Validation accuracy: 79.2%
# Minibatch loss at step 1550: 1.110732
# Minibatch accuracy: 68.8%
# Validation accuracy: 79.0%
# Minibatch loss at step 1600: 1.541696
# Minibatch accuracy: 68.8%
# Validation accuracy: 79.4%
# Minibatch loss at step 1650: 1.167592
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.6%
# Minibatch loss at step 1700: 1.079297
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.9%
# Minibatch loss at step 1750: 0.987345
# Minibatch accuracy: 68.8%
# Validation accuracy: 80.0%
# Minibatch loss at step 1800: 0.819791
# Minibatch accuracy: 68.8%
# Validation accuracy: 80.0%
# Minibatch loss at step 1850: 1.498459
# Minibatch accuracy: 62.5%
# Validation accuracy: 80.2%
# Minibatch loss at step 1900: 0.722920
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.6%
# Minibatch loss at step 1950: 1.173674
# Minibatch accuracy: 62.5%
# Validation accuracy: 79.9%
# Minibatch loss at step 2000: 0.641851
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.2%
# Minibatch loss at step 2050: 1.373126
# Minibatch accuracy: 62.5%
# Validation accuracy: 80.2%
# Minibatch loss at step 2100: 0.456251
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.3%
# Minibatch loss at step 2150: 1.280734
# Minibatch accuracy: 62.5%
# Validation accuracy: 80.5%
# Minibatch loss at step 2200: 0.462085
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.6%
# Minibatch loss at step 2250: 0.906568
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.8%
# Minibatch loss at step 2300: 0.903187
# Minibatch accuracy: 68.8%
# Validation accuracy: 80.5%
# Minibatch loss at step 2350: 0.664038
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.9%
# Minibatch loss at step 2400: 0.840719
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.0%
# Minibatch loss at step 2450: 0.838787
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.2%
# Minibatch loss at step 2500: 0.839110
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.1%
# Minibatch loss at step 2550: 0.842667
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.3%
# Minibatch loss at step 2600: 0.460500
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.3%
# Minibatch loss at step 2650: 0.951419
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.0%
# Minibatch loss at step 2700: 0.557510
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.0%
# Minibatch loss at step 2750: 1.252142
# Minibatch accuracy: 68.8%
# Validation accuracy: 80.4%
# Minibatch loss at step 2800: 0.621297
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.5%
# Minibatch loss at step 2850: 0.474549
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.6%
# Minibatch loss at step 2900: 0.858951
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.6%
# Minibatch loss at step 2950: 0.591781
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.7%
# Minibatch loss at step 3000: 0.596387
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.8%
# Minibatch loss at step 3050: 0.785360
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.0%
# Minibatch loss at step 3100: 0.999309
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.5%
# Minibatch loss at step 3150: 1.089613
# Minibatch accuracy: 62.5%
# Validation accuracy: 81.6%
# Minibatch loss at step 3200: 0.601788
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.8%
# Minibatch loss at step 3250: 0.740079
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.1%
# Minibatch loss at step 3300: 0.235687
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.2%
# Minibatch loss at step 3350: 0.554361
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.3%
# Minibatch loss at step 3400: 1.245206
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.3%
# Minibatch loss at step 3450: 0.683772
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.0%
# Minibatch loss at step 3500: 0.559736
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.7%
# Minibatch loss at step 3550: 0.525213
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.5%
# Minibatch loss at step 3600: 0.394718
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.2%
# Minibatch loss at step 3650: 0.994102
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.0%
# Minibatch loss at step 3700: 1.220136
# Minibatch accuracy: 62.5%
# Validation accuracy: 82.0%
# Minibatch loss at step 3750: 0.964468
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.3%
# Minibatch loss at step 3800: 0.283946
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.6%
# Minibatch loss at step 3850: 0.774190
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.8%
# Minibatch loss at step 3900: 0.753799
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.2%
# Minibatch loss at step 3950: 0.462096
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.4%
# Minibatch loss at step 4000: 0.631398
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.6%
# Minibatch loss at step 4050: 0.746177
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.8%
# Minibatch loss at step 4100: 0.763800
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.8%
# Minibatch loss at step 4150: 1.506874
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.7%
# Minibatch loss at step 4200: 0.689450
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.9%
# Minibatch loss at step 4250: 0.765554
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.6%
# Minibatch loss at step 4300: 1.114088
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.0%
# Minibatch loss at step 4350: 0.598071
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.8%
# Minibatch loss at step 4400: 0.860303
# Minibatch accuracy: 68.8%
# Validation accuracy: 83.1%
# Minibatch loss at step 4450: 0.834611
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.1%
# Minibatch loss at step 4500: 1.014226
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.2%
# Minibatch loss at step 4550: 0.851784
# Minibatch accuracy: 62.5%
# Validation accuracy: 83.3%
# Minibatch loss at step 4600: 0.485968
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.2%
# Minibatch loss at step 4650: 0.793096
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.4%
# Minibatch loss at step 4700: 0.721444
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.2%
# Minibatch loss at step 4750: 1.374080
# Minibatch accuracy: 62.5%
# Validation accuracy: 82.8%
# Minibatch loss at step 4800: 0.657163
# Minibatch accuracy: 68.8%
# Validation accuracy: 83.0%
# Minibatch loss at step 4850: 0.694459
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.2%
# Minibatch loss at step 4900: 0.225940
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.9%
# Minibatch loss at step 4950: 0.611060
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.0%
# Minibatch loss at step 5000: 1.344321
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.1%
# Minibatch loss at step 5050: 0.610457
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.2%
# Minibatch loss at step 5100: 0.454466
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.4%
# Minibatch loss at step 5150: 0.784363
# Minibatch accuracy: 68.8%
# Validation accuracy: 83.1%
# Minibatch loss at step 5200: 0.521585
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.2%
# Minibatch loss at step 5250: 0.518251
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.4%
# Minibatch loss at step 5300: 0.528626
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.4%
# Minibatch loss at step 5350: 0.498617
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.3%
# Minibatch loss at step 5400: 0.711075
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.8%
# Minibatch loss at step 5450: 0.670020
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.6%
# Minibatch loss at step 5500: 0.711030
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.7%
# Minibatch loss at step 5550: 0.604560
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.5%
# Minibatch loss at step 5600: 0.532795
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.3%
# Minibatch loss at step 5650: 0.794474
# Minibatch accuracy: 68.8%
# Validation accuracy: 83.8%
# Minibatch loss at step 5700: 0.752739
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.9%
# Minibatch loss at step 5750: 0.957516
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.8%
# Minibatch loss at step 5800: 0.609554
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.6%
# Minibatch loss at step 5850: 0.989598
# Minibatch accuracy: 68.8%
# Validation accuracy: 84.0%
# Minibatch loss at step 5900: 0.880307
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.7%
# Minibatch loss at step 5950: 0.731511
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.8%
# Minibatch loss at step 6000: 0.391836
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.0%
# Minibatch loss at step 6050: 0.830613
# Minibatch accuracy: 68.8%
# Validation accuracy: 83.9%
# Minibatch loss at step 6100: 0.956938
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.1%
# Minibatch loss at step 6150: 0.363068
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.0%
# Minibatch loss at step 6200: 1.699964
# Minibatch accuracy: 50.0%
# Validation accuracy: 84.0%
# Minibatch loss at step 6250: 0.975263
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.0%
# Minibatch loss at step 6300: 0.875735
# Minibatch accuracy: 68.8%
# Validation accuracy: 84.0%
# Minibatch loss at step 6350: 0.444317
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.0%
# Minibatch loss at step 6400: 0.322364
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.8%
# Minibatch loss at step 6450: 0.519643
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.0%
# Minibatch loss at step 6500: 0.709932
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.1%
# Minibatch loss at step 6550: 0.259785
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.2%
# Minibatch loss at step 6600: 0.389283
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.2%
# Minibatch loss at step 6650: 1.493986
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.0%
# Minibatch loss at step 6700: 0.555875
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.3%
# Minibatch loss at step 6750: 0.402326
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.1%
# Minibatch loss at step 6800: 0.782900
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.1%
# Minibatch loss at step 6850: 1.170757
# Minibatch accuracy: 56.2%
# Validation accuracy: 84.2%
# Minibatch loss at step 6900: 0.626234
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.8%
# Minibatch loss at step 6950: 0.621183
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.2%
# Minibatch loss at step 7000: 1.272436
# Minibatch accuracy: 56.2%
# Validation accuracy: 84.4%
# Minibatch loss at step 7050: 0.918708
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.5%
# Minibatch loss at step 7100: 0.731478
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.2%
# Minibatch loss at step 7150: 0.322048
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.2%
# Minibatch loss at step 7200: 0.792420
# Minibatch accuracy: 68.8%
# Validation accuracy: 84.3%
# Minibatch loss at step 7250: 0.636142
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.3%
# Minibatch loss at step 7300: 1.004643
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.3%
# Minibatch loss at step 7350: 0.377637
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.1%
# Minibatch loss at step 7400: 0.348103
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.4%
# Minibatch loss at step 7450: 0.495379
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.5%
# Minibatch loss at step 7500: 0.770847
# Minibatch accuracy: 68.8%
# Validation accuracy: 84.7%
# Minibatch loss at step 7550: 0.519733
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.5%
# Minibatch loss at step 7600: 0.441103
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.4%
# Minibatch loss at step 7650: 0.451200
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.7%
# Minibatch loss at step 7700: 0.441843
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.8%
# Minibatch loss at step 7750: 0.589441
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.9%
# Minibatch loss at step 7800: 0.697409
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.8%
# Minibatch loss at step 7850: 0.731884
# Minibatch accuracy: 68.8%
# Validation accuracy: 84.6%
# Minibatch loss at step 7900: 0.253429
# Minibatch accuracy: 100.0%
# Validation accuracy: 84.2%
# Minibatch loss at step 7950: 0.972268
# Minibatch accuracy: 68.8%
# Validation accuracy: 84.7%
# Minibatch loss at step 8000: 0.549974
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.7%
# Minibatch loss at step 8050: 0.438470
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.8%
# Minibatch loss at step 8100: 0.490128
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.8%
# Minibatch loss at step 8150: 0.651683
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.9%
# Minibatch loss at step 8200: 0.357182
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.9%
# Minibatch loss at step 8250: 0.459401
# Minibatch accuracy: 93.8%
# Validation accuracy: 84